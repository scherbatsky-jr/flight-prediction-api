# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/biraj/Desktop/Github/flight-prediction-api/datasets/Flights_2021/Flights_2021_1.csv')
# Out:
# /var/folders/yl/xw6g0vqx5cqfc51vfpmd7m1m0000gn/T/ipykernel_15120/1638981450.py:1: DtypeWarning: Columns (11,13,86,93) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/Users/biraj/Desktop/Github/flight-prediction-api/datasets/Flights_2021/Flights_2021_1.csv')

# %%
df.head()
# Out:
#    Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0  2021        1      1           2          6  2021-01-02
# 1  2021        1      1           3          7  2021-01-03
# 2  2021        1      1           4          1  2021-01-04
# 3  2021        1      1           7          4  2021-01-07
# 4  2021        1      1           8          5  2021-01-08
#
#   Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 0                        DL                            DL_CODESHARE
# 1                        DL                            DL_CODESHARE
# 2                        DL                            DL_CODESHARE
# 3                        DL                            DL_CODESHARE
# 4                        DL                            DL_CODESHARE
#
#    DOT_ID_Marketing_Airline IATA_Code_Marketing_Airline  ...  Div5Airport  \
# 0                     19790                          DL  ...          NaN
# ...

# %%
df['Cancelled'].value_counts()
# Out:
# 0.0    375229
# 1.0      4155
# Name: Cancelled, dtype: int64

# %%
df[df['Cancelled']==1.0]
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 43      2021        1      1          25          1  2021-01-25
# 491     2021        1      1          19          2  2021-01-19
# 498     2021        1      1          31          7  2021-01-31
# 509     2021        1      1          19          2  2021-01-19
# 516     2021        1      1          31          7  2021-01-31
# ...      ...      ...    ...         ...        ...         ...
# 379325  2021        1      1          31          7  2021-01-31
# 379328  2021        1      1          31          7  2021-01-31
# 379332  2021        1      1          31          7  2021-01-31
# 379373  2021        1      1          26          2  2021-01-26
# 379381  2021        1      1          31          7  2021-01-31
#
#        Marketing_Airline_Network Operated_or_Branded_Code_Share_Partners  \
# 43                            DL                            DL_CODESHARE
# ...

# %%
df['ArrDel15'].value_counts()
# Out:
# 0.0    443410
# 1.0     93572
# Name: ArrDel15, dtype: int64

# %%
df[df['ArrDelayMinutes']<15]
# Out:
#         Unnamed: 0  Year  Quarter  Month  DayofMonth  FlightDate  \
# 0                0  2021        1      1           5  2021-01-05
# 1                1  2021        1      1           5  2021-01-05
# 2                2  2021        1      1           5  2021-01-05
# 3                3  2021        1      1           5  2021-01-05
# 4                4  2021        1      1           6  2021-01-06
# ...            ...   ...      ...    ...         ...         ...
# 538035      538035  2021        4     12           2  2021-12-02
# 538036      538036  2021        4     12           2  2021-12-02
# 538037      538037  2021        4     12           2  2021-12-02
# 538038      538038  2021        4     12           2  2021-12-02
# 538039      538039  2021        4     12           2  2021-12-02
#
#         OriginAirportID Origin  DestAirportID Dest  ...  relative_humidity_2m  \
# 0                 11298    DFW          11433  DTW  ...             71.312126
# ...

# %%
df.columns
# Out:
# Index(['Year', 'Quarter', 'Month', 'DayofMonth', 'DayOfWeek', 'FlightDate',
#        'Marketing_Airline_Network', 'Operated_or_Branded_Code_Share_Partners',
#        'DOT_ID_Marketing_Airline', 'IATA_Code_Marketing_Airline',
#        ...
#        'Div5Airport', 'Div5AirportID', 'Div5AirportSeqID', 'Div5WheelsOn',
#        'Div5TotalGTime', 'Div5LongestGTime', 'Div5WheelsOff', 'Div5TailNum',
#        'Duplicate', 'Unnamed: 119'],
#       dtype='object', length=120)
